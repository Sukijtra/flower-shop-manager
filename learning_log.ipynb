# %% [markdown]
# # 🌷 Flower Shop Manager
#
# ## Learning Log
#
# Project: Flower Shop Manager
#
# Course: CP352301 การเขียนโปรแกรมสคริปต์
#
# ### Topics
#
# - Python OOP
# - API
# - SQLite
# - CLI
# - Data Analysis
# - Testing
